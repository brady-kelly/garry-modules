# %% [markdown]
# ## In the beginning was Hello World.
# It's inevitable, so lets get it out of the way. Python is most commonly used for scripting, AI and machine learning, and web development, and seldom for GUI work, so for a good while, all of our I/O will be to and from console. Output to console is via the [print](https://docs.python.org/3/library/functions.html#print) function.
# In its simplest use, this function takes an object and writes it to the console:

# %%
print("Hello world")
